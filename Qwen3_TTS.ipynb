# %%
# !pip install -q qwen-tts soundfile

# %%
# !pip install -U flash-attn --no-build-isolation

# %%
import torch
import soundfile as sf
from qwen_tts import Qwen3TTSModel
from IPython.display import Audio, display
# Out:
# WARNING:sox:SoX could not be found!
#
#     If you do not have SoX, proceed here:
#      - - - http://sox.sourceforge.net/ - - -
#
#     If you do (or think that you should) have SoX, double-check your
#     path variables.

# %%
import torch
import soundfile as sf
from qwen_tts import Qwen3TTSModel

model = Qwen3TTSModel.from_pretrained(
    "Qwen/Qwen3-TTS-12Hz-1.7B-CustomVoice",
    device_map="cuda:0",
    dtype=torch.bfloat16,
    attn_implementation="flash_attention_2",
)
# Out:
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
# batch inference
wavs, sr = model.generate_custom_voice(
    text=[
        "She said she would be here by noon.",
        "彼女は正午までにはここに来ると言っていました。"
    ],
    language=["English", "Japanese"],
    speaker=["Ryan", "Ono_Anna"],
    instruct=["", "Very happy."]
)
sf.write("output_custom_voice_1.wav", wavs[0], sr)
sf.write("output_custom_voice_2.wav", wavs[1], sr)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2150 for open-end generation.

# %%
print("Playing output_custom_voice_1.wav:")
display(Audio("output_custom_voice_1.wav"))
# Out:
# Playing output_custom_voice_1.wav:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Playing output_custom_voice_2.wav:")
display(Audio("output_custom_voice_2.wav"))
# Out:
# Playing output_custom_voice_2.wav:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
